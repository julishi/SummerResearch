# %%
import os
from PIL import Image, ImageFilter
import glob 
import random
import shutil 
import tensorflow as tf
import json
from tensorflow.examples.tutorials.mnist import input_data

#Declare the Empty list for Classes, otherwise it will be filled with irrelevant data
img_files = []

# set input dir path
path = '/Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials'

#Change current directory to Images 
os.chdir(path + '/ISIC-SubSet3')

for x in glob.glob('./*'):
    img_files.append(x.split('/')[1])

for i in img_files:
    print(i)
# Out:
# resized_MSK-1

# %%
if not os.path.isdir(path + '/ISIC-SubSet3/FilesDivided'):
    os.mkdir(path + '/ISIC-SubSet3/FilesDivided')

for i in img_files: 
    print(i)
    if not os.path.isdir(path + '/ISIC-SubSet3/FilesDivided/' + i):
        print("first path")
        os.mkdir(path + '/ISIC-SubSet3/FilesDivided/' + i)
        if not os.path.isdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/JSONFiles'):
            os.mkdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/JSONFiles')
        if not os.path.isdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/JPGFiles'):
            os.mkdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/JPGFiles')
        if not os.path.isdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/Malignant'):
            os.mkdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/Malignant')
        if not os.path.isdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/Benign'):
            os.mkdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/Benign')
# Out:
# resized_MSK-1
# first path

# %%
a = 0
added = 0
skipped = 0
for i in img_files:
    print(a)
    meta_data_label = []
    name = []
    json_files = []
    jpg_imgs = []
    all_json_files = glob.glob(path + '/ISIC-SubSet3/' + i + '/*.json')
    for x in all_json_files:
        json_files.append(x.split('/')[8])
    all_jpg_files = glob.glob(path + '/ISIC-SubSet3/' + i + '/*.jpg')
    for x in all_jpg_files:
        jpg_imgs.append(x.split('/')[8])
        
    a = a + 1

    x = 0
    for j in all_json_files:
        #print(j)
        with open(j) as f:
            print(x)
            meta_data = json.load(f)
            try:
            #    print("Inside try")
                meta_label = meta_data["meta"]["clinical"]["benign_malignant"]
            #    print(meta_label)
            #    print("Printing meta_data:")
                #print(meta_data_label[x])
                #name = meta_data["name"]
                #meta_name.append(meta_name)
                
                if meta_label == "benign" or meta_label == "malignant":
                    print(meta_label)
                    meta_data_label.append(meta_label)
                  #  print(meta_data_label[x])
                    shutil.copy(j, path + '/ISIC-SubSet3/FilesDivided/' + i + '/JSONFiles/')
                  #  print(path + '/ISIC-SubSet3/' + i + '/' + jpg_imgs[x])
                    img = Image.open(path + '/ISIC-SubSet3/' + i + '/' + jpg_imgs[x])
                    new_width  = 227
                    new_height = 227
                    img = img.resize((new_width, new_height), Image.ANTIALIAS)
                    img.save(path + '/ISIC-SubSet3/FilesDivided/' + i + '/JPGFiles/' + jpg_imgs[x], 'jpeg')
                    added = added + 1
                else: 
                    print("NULL Value Document:") 
                    print(meta_label)
                    print(j)
                    print("NULL Label: NOT COPYING")
            except:
                print("skipping" + json_files[x])
                skipped = skipped + 1
            #pprint(meta_data_label)
            x = x + 1
#    print("JSON Data extracted")
#   print(meta_data_label)
#   print("Total x")
#   print(x)

print("added")
print(added)
print("skipped")
print(skipped)
# Out:
# 0
# 0
# malignant
# 1
# malignant
# 2
# malignant
# 3
# benign
# 4
# benign
# 5
# benign
# 6
# benign
# 7
# benign
# 8
# benign
# 9
# benign
# 10
# benign
# 11
# benign
# 12
# benign
# 13
# benign
# 14
# benign
# 15
# benign
# 16
# benign
# 17
# benign
# 18
# benign
# 19
# benign
# 20
# benign
# 21
# benign
# 22
# benign
# 23
# benign
# 24
# benign
# 25
# malignant
# 26
# malignant
# 27
# malignant
# 28
# benign
# 29
# benign
# 30
# benign
# 31
# malignant
# 32
# malignant
# 33
# malignant
# 34
# malignant
# 35
# malignant
# 36
# malignant
# 37
# benign
# 38
# benign
# 39
# benign
# 40
# benign
# 41
# NULL Value Document:
# None
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/resized_MSK-1/ISIC_0011444.json
# NULL Label: NOT COPYING
# 42
# NULL Value Document:
# None
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/resized_MSK-1/ISIC_0011445.json
# NULL Label: NOT COPYING
# 43
# benign
# 44
# benign
# 45
# benign
# 46
# benign
# 47
# benign
# 48
# benign
# 49
# benign
# 50
# benign
# 51
# benign
# 52
# benign
# 53
# malignant
# 54
# benign
# 55
# malignant
# 56
# malignant
# 57
# malignant
# 58
# benign
# 59
# benign
# 60
# malignant
# 61
# benign
# 62
# NULL Value Document:
# None
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/resized_MSK-1/ISIC_0011465.json
# NULL Label: NOT COPYING
# 63
# NULL Value Document:
# None
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/resized_MSK-1/ISIC_0011466.json
# NULL Label: NOT COPYING
# 64
# benign
# 65
# benign
# 66
# benign
# 67
# benign
# 68
# malignant
# 69
# benign
# 70
# malignant
# 71
# malignant
# 72
# benign
# 73
# benign
# 74
# benign
# 75
# benign
# 76
# benign
# 77
# malignant
# 78
# malignant
# 79
# malignant
# 80
# malignant
# 81
# malignant
# 82
# malignant
# 83
# malignant
# 84
# malignant
# 85
# malignant
# 86
# malignant
# 87
# malignant
# 88
# malignant
# 89
# malignant
# 90
# malignant
# 91
# malignant
# 92
# malignant
# 93
# malignant
# 94
# malignant
# 95
# malignant
# 96
# malignant
# 97
# malignant
# 98
# malignant
# 99
# malignant
# 100
# malignant
# 101
# malignant
# 102
# malignant
# 103
# malignant
# 104
# malignant
# 105
# malignant
# 106
# malignant
# 107
# malignant
# 108
# malignant
# 109
# malignant
# 110
# malignant
# 111
# malignant
# 112
# malignant
# 113
# malignant
# 114
# malignant
# 115
# malignant
# 116
# malignant
# 117
# malignant
# 118
# malignant
# 119
# benign
# 120
# benign
# 121
# malignant
# 122
# benign
# 123
# malignant
# 124
# malignant
# 125
# malignant
# 126
# malignant
# 127
# malignant
# 128
# malignant
# 129
# malignant
# 130
# benign
# 131
# malignant
# 132
# malignant
# 133
# malignant
# 134
# malignant
# 135
# benign
# 136
# benign
# 137
# benign
# 138
# benign
# 139
# benign
# 140
# benign
# 141
# benign
# 142
# benign
# 143
# benign
# 144
# benign
# 145
# benign
# 146
# benign
# 147
# benign
# 148
# benign
# 149
# benign
# 150
# benign
# 151
# benign
# 152
# benign
# 153
# NULL Value Document:
# None
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/resized_MSK-1/ISIC_0011556.json
# NULL Label: NOT COPYING
# 154
# NULL Value Document:
# None
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/resized_MSK-1/ISIC_0011557.json
# NULL Label: NOT COPYING
# 155
# benign
# 156
# benign
# 157
# malignant
# 158
# benign
# 159
# benign
# 160
# benign
# 161
# benign
# 162
# benign
# 163
# malignant
# 164
# benign
# 165
# benign
# 166
# benign
# 167
# benign
# 168
# benign
# 169
# benign
# 170
# benign
# 171
# benign
# 172
# benign
# 173
# benign
# 174
# benign
# 175
# benign
# 176
# malignant
# 177
# benign
# 178
# benign
# 179
# NULL Value Document:
# None
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/resized_MSK-1/ISIC_0011582.json
# NULL Label: NOT COPYING
# 180
# NULL Value Document:
# None
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/resized_MSK-1/ISIC_0011583.json
# NULL Label: NOT COPYING
# 181
# benign
# 182
# benign
# 183
# benign
# 184
# benign
# 185
# benign
# 186
# malignant
# 187
# malignant
# 188
# malignant
# 189
# benign
# 190
# malignant
# 191
# malignant
# 192
# benign
# 193
# benign
# 194
# benign
# 195
# malignant
# 196
# benign
# 197
# benign
# 198
# benign
# 199
# benign
# 200
# benign
# 201
# benign
# 202
# benign
# 203
# benign
# 204
# benign
# 205
# benign
# 206
# benign
# 207
# malignant
# 208
# benign
# 209
# benign
# 210
# malignant
# 211
# malignant
# 212
# malignant
# 213
# malignant
# 214
# malignant
# 215
# malignant
# 216
# benign
# 217
# benign
# 218
# benign
# 219
# benign
# 220
# benign
# 221
# benign
# 222
# benign
# 223
# malignant
# 224
# malignant
# 225
# malignant
# 226
# benign
# 227
# benign
# 228
# benign
# 229
# benign
# 230
# benign
# 231
# benign
# 232
# benign
# 233
# benign
# 234
# benign
# 235
# benign
# 236
# benign
# 237
# benign
# 238
# benign
# 239
# malignant
# 240
# benign
# 241
# benign
# 242
# malignant
# 243
# malignant
# 244
# benign
# 245
# malignant
# 246
# malignant
