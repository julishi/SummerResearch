# %%
import os
from PIL import Image, ImageFilter
import glob 
import random
import shutil 
import tensorflow as tf
import json
from tensorflow.examples.tutorials.mnist import input_data

#Declare the Empty list for Classes, otherwise it will be filled with irrelevant data
img_files = []

# set input dir path
path = '/Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials'

#Change current directory to Images 
os.chdir(path + '/ISIC-SubSet3')

for x in glob.glob('./*'):
    img_files.append(x.split('/')[1])

for i in img_files:
    print(i)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)
# JIDEditorialImages

# %%
if not os.path.isdir(path + '/ISIC-SubSet3/FilesDivided'):
    os.mkdir(path + '/ISIC-SubSet3/FilesDivided')

for i in img_files: 
    print(i)
    if not os.path.isdir(path + '/ISIC-SubSet3/FilesDivided/' + i):
        print("first path")
        os.mkdir(path + '/ISIC-SubSet3/FilesDivided/' + i)
        if not os.path.isdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/JSONFiles'):
            os.mkdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/JSONFiles')
        if not os.path.isdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/JPGFiles'):
            os.mkdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/JPGFiles')
        if not os.path.isdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/Malignant'):
            os.mkdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/Malignant')
        if not os.path.isdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/Benign'):
            os.mkdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/Benign')
# Out:
# JIDEditorialImages
# first path

# %%
a = 0
added = 0
skipped = 0
for i in img_files:
    print(a)
    meta_data_label = []
    name = []
    json_files = []
    jpg_imgs_raw = []
    jpg_imgs_name = []
    all_json_files = glob.glob(path + '/ISIC-SubSet3/' + i + '/*.json')
    for x in all_json_files:
        json_files.append(x.split('/')[8])
#    print(all_json_files)
#    print("ALL JSON FILES")
#    print(json_files)
    all_jpg_files = glob.glob(path + '/ISIC-SubSet3/' + i + '/*.jpg')
    all_png_files = glob.glob(path + '/ISIC-SubSet3/' + i + '/*.png')
#    print(all_jpg_files)
#    print(all_png_files)
    for x in all_jpg_files:
        jpg_imgs_raw.append(x.split('/')[8])
        j = x.split('/')[8]
        k = j.split('.jpg')[0]
        jpg_imgs_name.append(k)
    for x in all_png_files:
        jpg_imgs_raw.append(x.split('/')[8])
        j = x.split('/')[8]
        k = j.split('.png')[0]
        jpg_imgs_name.append(k)
    print("raw")
    print(jpg_imgs_raw)
    print("name")
    print(jpg_imgs_name)

#    for i in jpg_imgs_raw:
#        print(i.split('.')[1])
#        if i.split('.')[1] == 'png':
#            print("TRUE")
#    print(jpg_imgs)

#    print()
#    print("ALL JPG FILES")
#    print(jpg_imgs) 
    #print(jpg_imgs[0])
    a = a + 1
    print(len(json_files))
    print(len(jpg_imgs))
#    print('json_files')
    x = 0
    for j in all_json_files:
        #print(j)
        with open(j) as f:
            print(x)
            #data = f.read()
            #output = json.load(f, dct["benign_malignant"])
            meta_data = json.load(f)
            try:
                print("Inside try")
                meta_label = meta_data["meta"]["clinical"]["benign_malignant"]
            #    print(meta_label)
            #    print("Printing meta_data:")
                #print(meta_data_label[x])
                #name = meta_data["name"]
                #meta_name.append(meta_name)
                print(meta_label)
                if meta_label == "benign" or meta_label == "malignant":
                    print("inside print")
                  #  print(meta_label)
                    meta_data_label.append(meta_label)
                    print("added")
                  #  print(meta_data_label[x])
                    shutil.copy(j, path + '/ISIC-SubSet3/FilesDivided/' + i + '/JSONFiles/')
                    print("copied")
                    print(path + '/ISIC-SubSet3/' + i + '/' + jpg_imgs_raw[x])
                    img = Image.open(path + '/ISIC-SubSet3/' + i + '/' + jpg_imgs_raw[x])
                    print("opened file")
                    if jpg_imgs_raw[x].split('.')[1] == 'png':
                        img = img.convert('RGB')
                    new_width  = 227
                    new_height = 227
                    img = img.resize((new_width, new_height), Image.ANTIALIAS)
                    img.save(path + '/ISIC-SubSet3/FilesDivided/' + i + '/JPGFiles/' + jpg_imgs_name[x] + '.jpg','jpeg')
                    added = added + 1
                    print("copied2")
                else: 
                    print("NULL Value Document:") 
                    print(meta_label)
                    print("NULL Label: NOT COPYING")
            except:
                print("skipping" + json_files[x])
                skipped = skipped + 1
            #pprint(meta_data_label)
            x = x + 1
#    print("JSON Data extracted")
#   print(meta_data_label)
#   print("Total x")
#   print(x)

print("added")
print(added)
print("skipped")
print(skipped)
# Out:
# 0
# raw
# ['ISIC_0024207.jpg', 'ISIC_0024208.jpg', 'ISIC_0024209.jpg', 'ISIC_0024210.jpg', 'ISIC_0024211.jpg', 'ISIC_0024212.jpg', 'ISIC_0024213.jpg', 'ISIC_0024214.jpg', 'ISIC_0024215.jpg', 'ISIC_0024216.jpg', 'ISIC_0024217.jpg', 'ISIC_0024218.jpg', 'ISIC_0024219.jpg', 'ISIC_0024220.jpg', 'ISIC_0024221.jpg', 'ISIC_0024222.jpg', 'ISIC_0024223.jpg', 'ISIC_0024224.jpg', 'ISIC_0024225.jpg', 'ISIC_0024226.jpg', 'ISIC_0024227.jpg', 'ISIC_0024228.jpg', 'ISIC_0024229.jpg', 'ISIC_0024230.jpg', 'ISIC_0024231.jpg', 'ISIC_0024232.jpg', 'ISIC_0024233.jpg', 'ISIC_0024234.jpg', 'ISIC_0024235.jpg', 'ISIC_0024236.jpg', 'ISIC_0024237.jpg', 'ISIC_0024238.jpg', 'ISIC_0024239.jpg', 'ISIC_0024240.jpg', 'ISIC_0024241.jpg', 'ISIC_0024242.jpg', 'ISIC_0024243.jpg', 'ISIC_0024244.jpg', 'ISIC_0024245.jpg', 'ISIC_0024246.jpg', 'ISIC_0024247.jpg', 'ISIC_0024248.jpg', 'ISIC_0024249.jpg', 'ISIC_0024250.jpg', 'ISIC_0024251.jpg', 'ISIC_0024252.jpg', 'ISIC_0024253.jpg', 'ISIC_0024254.jpg', 'ISIC_0024255.jpg', 'ISIC_0024256.jpg', 'ISIC_0024257.jpg', 'ISIC_0024258.jpg', 'ISIC_0024259.jpg', 'ISIC_0024261.jpg', 'ISIC_0024262.jpg', 'ISIC_0024263.jpg', 'ISIC_0024264.jpg', 'ISIC_0024265.jpg', 'ISIC_0024266.jpg', 'ISIC_0024267.jpg', 'ISIC_0024268.jpg', 'ISIC_0024270.jpg', 'ISIC_0024271.jpg', 'ISIC_0024272.jpg', 'ISIC_0024273.jpg', 'ISIC_0024274.jpg', 'ISIC_0024275.jpg', 'ISIC_0024276.jpg', 'ISIC_0024277.jpg', 'ISIC_0024278.jpg', 'ISIC_0024279.jpg', 'ISIC_0024280.jpg', 'ISIC_0024282.jpg', 'ISIC_0024283.jpg', 'ISIC_0024284.jpg', 'ISIC_0024285.jpg', 'ISIC_0024286.jpg', 'ISIC_0024287.jpg', 'ISIC_0024288.jpg', 'ISIC_0024289.jpg', 'ISIC_0024290.jpg', 'ISIC_0024291.jpg', 'ISIC_0024292.jpg', 'ISIC_0024293.jpg', 'ISIC_0024294.jpg', 'ISIC_0024295.jpg', 'ISIC_0024296.jpg', 'ISIC_0024297.jpg', 'ISIC_0024298.jpg', 'ISIC_0024299.jpg', 'ISIC_0024300.jpg', 'ISIC_0024301.jpg', 'ISIC_0024302.jpg', 'ISIC_0024303.jpg', 'ISIC_0024304.jpg', 'ISIC_0024305.jpg', 'ISIC_0024260.png', 'ISIC_0024269.png', 'ISIC_0024281.png', 'ISIC_0036065.png']
# name
# ['ISIC_0024207', 'ISIC_0024208', 'ISIC_0024209', 'ISIC_0024210', 'ISIC_0024211', 'ISIC_0024212', 'ISIC_0024213', 'ISIC_0024214', 'ISIC_0024215', 'ISIC_0024216', 'ISIC_0024217', 'ISIC_0024218', 'ISIC_0024219', 'ISIC_0024220', 'ISIC_0024221', 'ISIC_0024222', 'ISIC_0024223', 'ISIC_0024224', 'ISIC_0024225', 'ISIC_0024226', 'ISIC_0024227', 'ISIC_0024228', 'ISIC_0024229', 'ISIC_0024230', 'ISIC_0024231', 'ISIC_0024232', 'ISIC_0024233', 'ISIC_0024234', 'ISIC_0024235', 'ISIC_0024236', 'ISIC_0024237', 'ISIC_0024238', 'ISIC_0024239', 'ISIC_0024240', 'ISIC_0024241', 'ISIC_0024242', 'ISIC_0024243', 'ISIC_0024244', 'ISIC_0024245', 'ISIC_0024246', 'ISIC_0024247', 'ISIC_0024248', 'ISIC_0024249', 'ISIC_0024250', 'ISIC_0024251', 'ISIC_0024252', 'ISIC_0024253', 'ISIC_0024254', 'ISIC_0024255', 'ISIC_0024256', 'ISIC_0024257', 'ISIC_0024258', 'ISIC_0024259', 'ISIC_0024261', 'ISIC_0024262', 'ISIC_0024263', 'ISIC_0024264', 'ISIC_0024265', 'ISIC_0024266', 'ISIC_0024267', 'ISIC_0024268', 'ISIC_0024270', 'ISIC_0024271', 'ISIC_0024272', 'ISIC_0024273', 'ISIC_0024274', 'ISIC_0024275', 'ISIC_0024276', 'ISIC_0024277', 'ISIC_0024278', 'ISIC_0024279', 'ISIC_0024280', 'ISIC_0024282', 'ISIC_0024283', 'ISIC_0024284', 'ISIC_0024285', 'ISIC_0024286', 'ISIC_0024287', 'ISIC_0024288', 'ISIC_0024289', 'ISIC_0024290', 'ISIC_0024291', 'ISIC_0024292', 'ISIC_0024293', 'ISIC_0024294', 'ISIC_0024295', 'ISIC_0024296', 'ISIC_0024297', 'ISIC_0024298', 'ISIC_0024299', 'ISIC_0024300', 'ISIC_0024301', 'ISIC_0024302', 'ISIC_0024303', 'ISIC_0024304', 'ISIC_0024305', 'ISIC_0024260', 'ISIC_0024269', 'ISIC_0024281', 'ISIC_0036065']
# 100
# 100
# 0
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024207.jpg
# opened file
# copied2
# 1
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024208.jpg
# opened file
# copied2
# 2
# Inside try
# skippingISIC_0024209.json
# 3
# Inside try
# skippingISIC_0024210.json
# 4
# Inside try
# skippingISIC_0024211.json
# 5
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024212.jpg
# opened file
# copied2
# 6
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024213.jpg
# opened file
# copied2
# 7
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024214.jpg
# opened file
# copied2
# 8
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024215.jpg
# opened file
# copied2
# 9
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024216.jpg
# opened file
# copied2
# 10
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024217.jpg
# opened file
# copied2
# 11
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024218.jpg
# opened file
# copied2
# 12
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024219.jpg
# opened file
# copied2
# 13
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024220.jpg
# opened file
# copied2
# 14
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024221.jpg
# opened file
# copied2
# 15
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024222.jpg
# opened file
# copied2
# 16
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024223.jpg
# opened file
# copied2
# 17
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024224.jpg
# opened file
# copied2
# 18
# Inside try
# skippingISIC_0024225.json
# 19
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024226.jpg
# opened file
# copied2
# 20
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024227.jpg
# opened file
# copied2
# 21
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024228.jpg
# opened file
# copied2
# 22
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024229.jpg
# opened file
# copied2
# 23
# Inside try
# skippingISIC_0024230.json
# 24
# Inside try
# skippingISIC_0024231.json
# 25
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024232.jpg
# opened file
# copied2
# 26
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024233.jpg
# opened file
# copied2
# 27
# Inside try
# skippingISIC_0024234.json
# 28
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024235.jpg
# opened file
# copied2
# 29
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024236.jpg
# opened file
# copied2
# 30
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024237.jpg
# opened file
# copied2
# 31
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024238.jpg
# opened file
# copied2
# 32
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024239.jpg
# opened file
# copied2
# 33
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024240.jpg
# opened file
# copied2
# 34
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024241.jpg
# opened file
# copied2
# 35
# Inside try
# skippingISIC_0024242.json
# 36
# Inside try
# skippingISIC_0024243.json
# 37
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024244.jpg
# opened file
# copied2
# 38
# Inside try
# skippingISIC_0024245.json
# 39
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024246.jpg
# opened file
# copied2
# 40
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024247.jpg
# opened file
# copied2
# 41
# Inside try
# skippingISIC_0024248.json
# 42
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024249.jpg
# opened file
# copied2
# 43
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024250.jpg
# opened file
# copied2
# 44
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024251.jpg
# opened file
# copied2
# 45
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024252.jpg
# opened file
# copied2
# 46
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024253.jpg
# opened file
# copied2
# 47
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024254.jpg
# opened file
# copied2
# 48
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024255.jpg
# opened file
# copied2
# 49
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024256.jpg
# opened file
# copied2
# 50
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024257.jpg
# opened file
# copied2
# 51
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024258.jpg
# opened file
# copied2
# 52
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024259.jpg
# opened file
# copied2
# 53
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024261.jpg
# opened file
# copied2
# 54
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024262.jpg
# opened file
# copied2
# 55
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024263.jpg
# opened file
# copied2
# 56
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024264.jpg
# opened file
# copied2
# 57
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024265.jpg
# opened file
# copied2
# 58
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024266.jpg
# opened file
# copied2
# 59
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024267.jpg
# opened file
# copied2
# 60
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024268.jpg
# opened file
# copied2
# 61
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024270.jpg
# opened file
# copied2
# 62
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024271.jpg
# opened file
# copied2
# 63
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024272.jpg
# opened file
# copied2
# 64
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024273.jpg
# opened file
# copied2
# 65
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024274.jpg
# opened file
# copied2
# 66
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024275.jpg
# opened file
# copied2
# 67
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024276.jpg
# opened file
# copied2
# 68
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024277.jpg
# opened file
# copied2
# 69
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024278.jpg
# opened file
# copied2
# 70
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024279.jpg
# opened file
# copied2
# 71
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024280.jpg
# opened file
# copied2
# 72
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024282.jpg
# opened file
# copied2
# 73
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024283.jpg
# opened file
# copied2
# 74
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024284.jpg
# opened file
# copied2
# 75
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024285.jpg
# opened file
# copied2
# 76
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024286.jpg
# opened file
# copied2
# 77
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024287.jpg
# opened file
# copied2
# 78
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024288.jpg
# opened file
# copied2
# 79
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024289.jpg
# opened file
# copied2
# 80
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024290.jpg
# opened file
# copied2
# 81
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024291.jpg
# opened file
# copied2
# 82
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024292.jpg
# opened file
# copied2
# 83
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024293.jpg
# opened file
# copied2
# 84
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024294.jpg
# opened file
# copied2
# 85
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024295.jpg
# opened file
# copied2
# 86
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024296.jpg
# opened file
# copied2
# 87
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024297.jpg
# opened file
# copied2
# 88
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024298.jpg
# opened file
# copied2
# 89
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024299.jpg
# opened file
# copied2
# 90
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024300.jpg
# opened file
# copied2
# 91
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024301.jpg
# opened file
# copied2
# 92
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024302.jpg
# opened file
# copied2
# 93
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024303.jpg
# opened file
# copied2
# 94
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024304.jpg
# opened file
# copied2
# 95
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024305.jpg
# opened file
# copied2
# 96
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024260.png
# opened file
# copied2
# 97
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024269.png
# opened file
# copied2
# 98
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0024281.png
# opened file
# copied2
# 99
# Inside try
# malignant
# inside print
# added
# copied
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/JIDEditorialImages/ISIC_0036065.png
# opened file
# copied2
# added
# 89
# skipped
# 11

# %%
for i in meta_data_label: 
    print(i)
# Out:
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant
# malignant

# %%
print(len(meta_data_label))
# Out:
# 89
