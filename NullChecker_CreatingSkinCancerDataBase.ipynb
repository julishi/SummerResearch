# %%
import os
from PIL import Image, ImageFilter
import glob 
import random
import shutil 
import tensorflow as tf
import json
from tensorflow.examples.tutorials.mnist import input_data

#Declare the Empty list for Classes, otherwise it will be filled with irrelevant data
img_files = []

# set input dir path
path = '/Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials'

#Change current directory to Images 
os.chdir(path + '/ISIC-SubSet3')

for x in glob.glob('./*'):
    img_files.append(x.split('/')[1])

for i in img_files:
    print(i)
# Out:
# MSK-2

# %%
if not os.path.isdir(path + '/ISIC-SubSet3/FilesDivided'):
    os.mkdir(path + '/ISIC-SubSet3/FilesDivided')

for i in img_files: 
    print(i)
    if not os.path.isdir(path + '/ISIC-SubSet3/FilesDivided/' + i):
        print("first path")
        os.mkdir(path + '/ISIC-SubSet3/FilesDivided/' + i)
        if not os.path.isdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/JSONFiles'):
            os.mkdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/JSONFiles')
        if not os.path.isdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/JPGFiles'):
            os.mkdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/JPGFiles')
        if not os.path.isdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/Malignant'):
            os.mkdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/Malignant')
        if not os.path.isdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/Benign'):
            os.mkdir(path + '/ISIC-SubSet3/FilesDivided/' + i + '/Benign')
# Out:
# MSK-2
# first path

# %%
a = 0
for i in img_files:
    print(a)
    meta_data_label = []
    name = []
    json_files = []
    jpg_imgs = []
    all_json_files = glob.glob(path + '/ISIC-SubSet3/' + i + '/*.json')
    for x in all_json_files:
        json_files.append(x.split('/')[8])
#    print("ALL JSON FILES")
#    print(json_files)
    all_jpg_files = glob.glob(path + '/ISIC-SubSet3/' + i + '/*.jpg')
    for x in all_jpg_files:
        jpg_imgs.append(x.split('/')[8])
#    print()
#    print("ALL JPG FILES")
#    print(jpg_imgs) 
    #print(jpg_imgs[0])
    a = a + 1

#    print('json_files')
    x = 0
    for j in all_json_files:
        #print(j)
        with open(j) as f:
            print(x)
            #data = f.read()
            #output = json.load(f, dct["benign_malignant"])
            meta_data = json.load(f)
            try:
            #    print("Inside try")
                meta_label = meta_data["meta"]["clinical"]["benign_malignant"]
            #    print(meta_label)
            #    print("Printing meta_data:")
                #print(meta_data_label[x])
                #name = meta_data["name"]
                #meta_name.append(meta_name)
                
                if meta_label is None:
                    print("Confirm it's null:") 
                    print(meta_label)
                    print("NULL Label: NOT COPYING")
                else:
                    print(meta_label)
                    meta_data_label.append(meta_label)
                  #  print(meta_data_label[x])
                    shutil.copy(j, path + '/ISIC-SubSet3/FilesDivided/' + i + '/JSONFiles/')
                    print(path + '/ISIC-SubSet3/' + i + '/' + jpg_imgs[x])
                    img = Image.open(path + '/ISIC-SubSet3/' + i + '/' + jpg_imgs[x])
                    new_width  = 227
                    new_height = 227
                    img = img.resize((new_width, new_height), Image.ANTIALIAS)
                    img.save(path + '/ISIC-SubSet3/FilesDivided/' + i + '/JPGFiles/' + jpg_imgs[x], 'jpeg')
            except:
                print("skipping" + json_files[x])
            #pprint(meta_data_label)
            x = x + 1
#    print("JSON Data extracted")
#   print(meta_data_label)
#   print("Total x")
#   print(x)
# Out:
# 0
# 0
# malignant
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/MSK-2/ISIC_0009868.jpg
# 1
# benign
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/MSK-2/ISIC_0009869.jpg
# 2
# benign
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/MSK-2/ISIC_0009870.jpg
# 3
# benign
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/MSK-2/ISIC_0009871.jpg
# 4
# benign
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/MSK-2/ISIC_0009872.jpg
# 5
# benign
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/MSK-2/ISIC_0009873.jpg
# 6
# benign
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/MSK-2/ISIC_0009874.jpg
# 7
# benign
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet3/MSK-2/ISIC_0009875.jpg
# 8
# benign
# ...

# %%
for i in meta_data_label: 
    print(i)

# %%
a = "null"
if a == "null":
    print("Skipping")
else:
    print("Copying")

# %%
for i in meta_data_label:
    if i == "Null":
        print("Null")
    if i == "null":
        print("null")
    else: 
        print(i)
