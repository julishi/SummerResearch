# %%
import os
from PIL import Image, ImageFilter
import glob 
import random
import shutil 
import tensorflow as tf
import json
from tensorflow.examples.tutorials.mnist import input_data

#set training image ratio
TRAIN_PER = 20 
#set test image ratio
TEST_PER = 5 

#set output size
#We will use Alexnet image sizes
out_width = 224
out_height = 224

#Declare the Empty list for Classes, otherwise it will be filled with irrelevant data
img_files = []
meta_data_label = []
json_files = []
jpg_imgs = []
# set input dir path
path = '/Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials'

#Change current directory to Images 
os.chdir(path + '/ISIC-SubSet2')

for x in glob.glob('./*'):
    img_files.append(x.split('/')[1])

for i in img_files:
    print(i)

# %%
if not os.path.isdir(path + '/ISIC-SubSet2/FilesDivided'):
    os.mkdir(path + '/ISIC-SubSet2/FilesDivided')

for i in img_files: 
    print(i)
    if not os.path.isdir(path + '/ISIC-SubSet2/FilesDivided/' + i):
        print("first path")
        os.mkdir(path + '/ISIC-SubSet2/FilesDivided/' + i)
        if not os.path.isdir(path + '/ISIC-SubSet2/FilesDivided/' + i + '/JSONFiles'):
            os.mkdir(path + '/ISIC-SubSet2/FilesDivided/' + i + '/JSONFiles')
        if not os.path.isdir(path + '/ISIC-SubSet2/FilesDivided/' + i + '/JPGFiles'):
            os.mkdir(path + '/ISIC-SubSet2/FilesDivided/' + i + '/JPGFiles')
        if not os.path.isdir(path + '/ISIC-SubSet2/FilesDivided/' + i + '/Malignant'):
            os.mkdir(path + '/ISIC-SubSet2/FilesDivided/' + i + '/Malignant')
        if not os.path.isdir(path + '/ISIC-SubSet2/FilesDivided/' + i + '/Benign'):
            os.mkdir(path + '/ISIC-SubSet2/FilesDivided/' + i + '/Benign')

# %%
a = 0
for i in img_files:
    print(a)
    all_json_files = glob.glob(path + '/ISIC-SubSet2/' + i + '/*.json')
    for x in all_json_files:
        json_files.append(x.split('/')[8])
    print("ALL JSON FILES")
    print(json_files)
    all_jpg_files = glob.glob(path + '/ISIC-SubSet2/' + i + '/*.jpg')
    for x in all_jpg_files:
        jpg_imgs.append(x.split('/')[8])
    print()
    print("ALL JPG FILES")
    print(jpg_imgs) 
    #print(jpg_imgs[0])
    a = a + 1

    print('json_files')
    x = 0
    for j in all_json_files:
        #print(j)
        with open(j) as f:
            x = x + 1
            print(x)
            #data = f.read()
            #output = json.load(f, dct["benign_malignant"])
            meta_data = json.load(f)
            meta_label = meta_data["meta"]["clinical"]["benign_malignant"]
            meta_data_label.append(meta_label)
            #pprint(meta_data_label)
        shutil.copy(j, path + '/ISIC-SubSet2/FilesDivided/' + i + '/JSONFiles/')
    print("JSON Data extracted")
    print(meta_data_label)
    print("Total x")
    print(x)


    print()
    print('jpg_files')
    x = 0
    print(jpg_imgs)
    for j in all_jpg_files:
        #print(j)
        img = Image.open(j)
        new_width  = 227
        new_height = 227
        img = img.resize((new_width, new_height), Image.ANTIALIAS)
        img.save(path + '/ISIC-SubSet2/FilesDivided/' + i + '/JPGFiles/' + jpg_imgs[x] + '.jpg', 'jpeg')
        #img.save(path + '/ISIC-SubSet2/FilesDivided/' + i + '/JPGFiles/' + meta_data_label[x] + jpg_imgs[x] +'.jpg', 'jpeg')
        print(jpg_imgs[x])
        print(meta_data_label[x])
        #shutil.copy(i, path + '/ISIC-SubSet/FilesDivided/UDA-2/JPGFiles/')
        print("Pre-X" + str(x))
        #print(x)
        x = x + 1
        print("Post-X")
        print(x)

# %%
#Rename the UDA-1 Files 
#Declare the Empty list for Classes, otherwise it will be filled with irrelevant data
file_rename = []
file_renamed = []
# set input dir path
path = '/Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials'

#Change current directory to Images 
os.chdir(path + '/ISIC-SubSet2/FilesDivided/UDA-1/JPGFiles')
#print (os.listdir(os.getcwd()))

for x in glob.glob('./*'):
    file_rename.append(x.split('/')[1])

for i in file_rename:
    print(i)

for i in jpg_imgs:
    print(i)
x = 0
for i in file_rename:
    os.rename(i, jpg_imgs[x])
    x = x + 1
print("renames")
os.chdir(path + '/ISIC-SubSet2/FilesDivided/UDA-1/JPGFiles')
for x in glob.glob('./*'):
    file_renamed.append(x.split('/')[1])
for i in file_renamed:
    print(i)

# %%
#print the renamed files in UDA-1
for i in file_renamed:
    print(i)

# %%
#DOESNT WORK 100%
#Rename the UDA-2 Files
#Declare the Empty list for Classes, otherwise it will be filled with irrelevant data
#file_rename = []
#file_renamed = []
# set input dir path
#path = '/Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials'

#Change current directory to Images 
#os.chdir(path + '/ISIC-SubSet2/FilesDivided/UDA-2/JPGFiles')
#print (os.listdir(os.getcwd()))

#for x in glob.glob('./*'):
#    file_rename.append(x.split('/')[1])

#for i in file_rename:
#    print(i)

#for i in jpg_imgs:
#    print(i)
#x = 0
#for i in file_rename:
#    os.rename(i, jpg_imgs[x])
#    x = x + 1
#print("renames")
#os.chdir(path + '/ISIC-SubSet2/FilesDivided/UDA-2/JPGFiles')
#for x in glob.glob('./*'):
#    file_renamed.append(x.split('/')[1])
#for i in file_renamed:
#    print(i)

# %%
jpg_files = []
jpg_files_copied = glob.glob(path + '/ISIC-SubSet2/FilesDivided/UDA-2/JPGFiles/*.jpg')

for x in jpg_files_copied:
    jpg_files.append(x.split('/')[10])
print(jpg_files)    
#print(meta_data_label)
#print(len(meta_data_label))
x = 0
#print(jpg_files_copied)
#print(jpg_files_copied[2])
#for i in meta_data_label:  
#    if i.lower() == "malignant":
#        print("TRUE")
#        #shutil.copy(jpg_files_copied[x], path + '/ISIC-SubSet2/FilesDivided/UDA-2/JPGFiles/')
#    else:
#        print("FALSE")
#    x = x + 1

# %%
import json
from pprint import pprint

x = 0;
for i in all_json_files:
    with open(i) as f:
        #data = f.read()
        #output = json.load(f, dct["benign_malignant"])
        meta_data = json.load(f)
        meta_label = meta_data["meta"]["clinical"]["benign_malignant"]
    pprint(meta_label)
    x = x + 1
    
#data = f.read()
#json.load(f, '"\\"meta\\clinical\\benign_malignant"')

#data = json.load(f)
#pprint(data)
#print(data['meta'][1]['diagnosis'])
print(x)
