# %%
import os
from PIL import Image, ImageFilter
import glob 
import random
import shutil 
import tensorflow as tf
import json
from tensorflow.examples.tutorials.mnist import input_data

#set input dir path
path = '/Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided'

# %%
all_benign = []
all_benign = glob.glob(path + '/All_Benign/*')

for i in all_benign: 
    print(i)
benign_amount = len(all_benign)
print(benign_amount)
# Out:
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Benign/ISIC_0000000.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Benign/ISIC_0000001.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Benign/ISIC_0000003.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Benign/ISIC_0000005.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Benign/ISIC_0000006.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Benign/ISIC_0000007.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Benign/ISIC_0000008.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Benign/ISIC_0000009.jpg
# ...

# %%
all_mal = []
all_mal = glob.glob(path + '/All_Malignant/*')

for i in all_mal: 
    print(i)
mal_amount = len(all_mal)
print(mal_amount)
# Out:
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Malignant/ISIC_0000002.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Malignant/ISIC_0000004.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Malignant/ISIC_0000013.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Malignant/ISIC_0000022.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Malignant/ISIC_0000026.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Malignant/ISIC_0000029.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Malignant/ISIC_0000030.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Malignant/ISIC_0000031.jpg
# ...

# %%
import math
Train_Num_Benign = math.floor(0.80 * benign_amount)
Train_Num_Mal = math.floor(0.80 * mal_amount)
print(Train_Num_Benign)
print(Train_Num_Mal)

Test_Num_Benign = benign_amount - Train_Num_Benign
Test_Num_Mal = mal_amount - Train_Num_Mal
print(Test_Num_Benign)
print(Test_Num_Mal)
# Out:
# 4778
# 1588
# 1195
# 397

# %%
#Change current directory to Images 

current_path = '/Users/julianashihadeh/Desktop/testProject/SummerResearchImplementations/AlexNet_1.0/'
os.chdir(current_path)

f = open("train_melanoma.txt", "w+")

for i in range(4778):
    f.write(all_benign[i] + " 0 \r\n")
for i in range(1588):
    f.write(all_mal[i] + " 1 \r\n")

# %%
f = open("val_melanoma.txt", "w+")

for i in range(1195):
    f.write(all_benign[4778 + i] + " 0 \r\n")
for i in range(397):
    f.write(all_mal[1588 + i] + " 1 \r\n")

# %%
print(all_benign[9041])
print(all_benign[9040])
print(all_benign[9040 + 2259])
print(all_benign[11299])
# Out:
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Benign/ISIC_0031149.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Benign/ISIC_0031148.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Benign/ISIC_0034320.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Benign/ISIC_0034320.jpg

# %%
print(all_mal[2920])
print(all_mal[2919])
print(all_mal[2919 + 729])
print(all_mal[3648])
# Out:
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Malignant/ISIC_0031605.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Malignant/ISIC_0031599.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Malignant/ISIC_0034317.jpg
# /Users/julianashihadeh/Desktop/testProject/SummerResearchTutorials/ISIC-SubSet/FilesDivided/All_Malignant/ISIC_0034317.jpg
